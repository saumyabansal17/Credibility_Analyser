# %%
# !pip install -U nlp
# !pip install -U transformers
# Out:
# Requirement already up-to-date: nlp in /home/pranav/anaconda3/lib/python3.7/site-packages (0.4.0)
# Requirement already satisfied, skipping upgrade: filelock in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (3.0.10)
# Requirement already satisfied, skipping upgrade: numpy in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (1.21.0)
# Requirement already satisfied, skipping upgrade: pyarrow>=0.16.0 in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (4.0.1)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (4.31.1)
# Requirement already satisfied, skipping upgrade: dill in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (0.3.4)
# Requirement already satisfied, skipping upgrade: pandas in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (0.24.2)
# Requirement already satisfied, skipping upgrade: requests>=2.19.0 in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (2.21.0)
# Requirement already satisfied, skipping upgrade: xxhash in /home/pranav/anaconda3/lib/python3.7/site-packages (from nlp) (2.0.2)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /home/pranav/anaconda3/lib/python3.7/site-packages (from pandas->nlp) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /home/pranav/anaconda3/lib/python3.7/site-packages (from pandas->nlp) (2.8.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->nlp) (1.24.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->nlp) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->nlp) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->nlp) (2019.3.9)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/pranav/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->nlp) (1.12.0)
# Collecting sentencepiece
#   Using cached https://files.pythonhosted.org/packages/aa/71/bb7d64dcd80a6506146397bca7310d5a8684f0f9ef035f03affb657f1aec/sentencepiece-0.1.96.tar.gz
# Building wheels for collected packages: sentencepiece
#   Building wheel for sentencepiece (setup.py) ... error
#   Complete output from command /home/pranav/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-tym23p7w/sentencepiece/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-tnspgu3x --python-tag cp37:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/sentencepiece
#   copying src/sentencepiece/__init__.py -> build/lib.linux-x86_64-3.7/sentencepiece
#   copying src/sentencepiece/sentencepiece_model_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#   copying src/sentencepiece/sentencepiece_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#   running build_ext
#   Package sentencepiece was not found in the pkg-config search path.
#   Perhaps you should add the directory containing `sentencepiece.pc'
#   to the PKG_CONFIG_PATH environment variable
#   No package 'sentencepiece' found
#   Cloning into 'sentencepiece'...
#   Note: switching to 'd8711f55d9b2cb9c77a00adcc18108482b29b675'.
#
#   You are in 'detached HEAD' state. You can look around, make experimental
#   changes and commit them, and you can discard any commits you make in this
#   state without impacting any branches by switching back to a branch.
#
#   If you want to create a new branch to retain commits you create, you may
#   do so (now or later) by using -c with the switch command. Example:
#
#     git switch -c <new-branch-name>
#
#   Or undo this operation with:
#
#     git switch -
#
#   Turn off this advice by setting config variable advice.detachedHead to false
#
#   ./build_bundled.sh: 15: cmake: not found
#   make: *** No targets specified and no makefile found.  Stop.
#   make: *** No rule to make target 'install'.  Stop.
#   Package sentencepiece was not found in the pkg-config search path.
#   Perhaps you should add the directory containing `sentencepiece.pc'
#   to the PKG_CONFIG_PATH environment variable
#   No package 'sentencepiece' found
#   Failed to find sentencepiece pkg-config
#
#   ----------------------------------------
#   Failed building wheel for sentencepiece
#   Running setup.py clean for sentencepiece
# Failed to build sentencepiece
# Installing collected packages: sentencepiece
#   Running setup.py install for sentencepiece ... error
#     Complete output from command /home/pranav/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-tym23p7w/sentencepiece/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /tmp/pip-record-73i8k47n/install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.7
#     creating build/lib.linux-x86_64-3.7/sentencepiece
#     copying src/sentencepiece/__init__.py -> build/lib.linux-x86_64-3.7/sentencepiece
#     copying src/sentencepiece/sentencepiece_model_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#     copying src/sentencepiece/sentencepiece_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#     running build_ext
#     Package sentencepiece was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `sentencepiece.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'sentencepiece' found
#     mkdir: cannot create directory ‘bundled’: File exists
#     fatal: destination path 'sentencepiece' already exists and is not an empty directory.
#     fatal: destination path 'sentencepiece' already exists and is not an empty directory.
#     mkdir: cannot create directory ‘build’: File exists
#     ./build_bundled.sh: 15: cmake: not found
#     make: *** No targets specified and no makefile found.  Stop.
#     make: *** No rule to make target 'install'.  Stop.
#     Package sentencepiece was not found in the pkg-config search path.
#     Perhaps you should add the directory containing `sentencepiece.pc'
#     to the PKG_CONFIG_PATH environment variable
#     No package 'sentencepiece' found
#     Failed to find sentencepiece pkg-config
#
#     ----------------------------------------
# Command "/home/pranav/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-install-tym23p7w/sentencepiece/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /tmp/pip-record-73i8k47n/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /tmp/pip-install-tym23p7w/sentencepiece/
# Requirement already up-to-date: transformers in /home/pranav/anaconda3/lib/python3.7/site-packages (4.8.1)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (4.31.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (0.0.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (5.1)
# Requirement already satisfied, skipping upgrade: requests in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (2.21.0)
# Requirement already satisfied, skipping upgrade: sacremoses in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (0.0.45)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (2021.4.4)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (1.21.0)
# Requirement already satisfied, skipping upgrade: huggingface-hub==0.0.12 in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (0.0.12)
# Requirement already satisfied, skipping upgrade: packaging in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (20.0)
# Requirement already satisfied, skipping upgrade: filelock in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (3.0.10)
# Requirement already satisfied, skipping upgrade: tokenizers<0.11,>=0.10.1 in /home/pranav/anaconda3/lib/python3.7/site-packages (from transformers) (0.10.3)
# Requirement already satisfied, skipping upgrade: zipp>=0.3.2 in /home/pranav/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers) (0.3.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2019.3.9)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests->transformers) (1.24.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/pranav/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied, skipping upgrade: click in /home/pranav/anaconda3/lib/python3.7/site-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied, skipping upgrade: six in /home/pranav/anaconda3/lib/python3.7/site-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied, skipping upgrade: joblib in /home/pranav/anaconda3/lib/python3.7/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied, skipping upgrade: typing-extensions in /home/pranav/anaconda3/lib/python3.7/site-packages (from huggingface-hub==0.0.12->transformers) (3.10.0.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /home/pranav/anaconda3/lib/python3.7/site-packages (from packaging->transformers) (2.3.1)

# %%
import random
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import BatchSampler, SequentialSampler
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import sentencepiece

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = AutoTokenizer.from_pretrained("joeddav/xlm-roberta-large-xnli", padding=True)
filename = "model.sav"
model = pickle.load(open(filename,'rb'))
model.config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-155a8f816c0b> in <module>
#       6 from torch.utils.data import BatchSampler, SequentialSampler
#       7 from transformers import AutoTokenizer, AutoModelForSequenceClassification
# ----> 8 import sentencepiece
#       9
#      10 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#
# ModuleNotFoundError: No module named 'sentencepiece'

# %%
temp_data = pd.read_csv('./temp.csv', encoding='utf8')
temp_dataset = MyDataset(temp_data, tokenizer, labels=False)
temp_dataloader = DataLoader(dataset=temp_dataset,
                              sampler=BatchSampler(
                                    SequentialSampler(temp_dataset), 
                                    batch_size=8, drop_last=False), shuffle=False)
temp_preds = submission_predict(model, temp_dataloader, device)
